# %%
from config_diff import get_config_h, get_diff, get_config_h_diff
from rich.markdown import Markdown
from rich import print as rprint

# %%
left="http://mpsd-octopus-code-staging.desy.de/buildbot/#/builders/208/builds/3"
right="https://www.octopus-code.org/buildbot/#/builders/56/builds/2274"
get_config_h_diff(left,right,"spack","eb")
# Out:
# --- spack
#
# +++ eb
#
# @@ -2,10 +2,10 @@
#
#  /* config.h.in.  Generated from configure.ac by autoheader.  */
#
#  /* date when configure was launched */
# -#define BUILD_TIME "Thu Feb 29 16:33:00 CET 2024"
# +#define BUILD_TIME "Thu Feb 29 14:17:29 CET 2024"
#
#  /* C compiler */
# -#define CC
# "/scratch/mlang/mpsd-software-root/24a/sandybridge/spack/opt/spack/linux-debian11-x86_64_v2/gcc-10.2.1/intel-oneapi
# -compilers-2022.2.1-fvxmp3cuzza42yvwjghjou75edg55zog/compiler/2022.2.1/linux/bin/intel64/icc (unknown)"
# +#define CC "icc "
#
#  /* C compiler flags */
#  #define CFLAGS "-O3 -xHost -ftz -fp-speculation=safe -fp-model source -traceback -Wall"
# @@ -14,7 +14,7 @@
#
#  #define CFLAGS_EXTRA ""
#
#  /* C++ compiler */
# -#define CXX
# "/scratch/mlang/mpsd-software-root/24a/sandybridge/spack/opt/spack/linux-debian11-x86_64_v2/gcc-10.2.1/intel-oneapi
# -compilers-2022.2.1-fvxmp3cuzza42yvwjghjou75edg55zog/compiler/2022.2.1/linux/bin/intel64/icpc (unknown)"
# +#define CXX "icpc "
# ...
