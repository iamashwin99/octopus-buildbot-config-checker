# %%
from config_diff import get_config_h, get_diff, get_config_h_diff
from rich.markdown import Markdown
from rich import print as rprint

# %%
# Builder map for branch "fix-elpa-m4" revision "51be2da027081a8345286439fefa22cee15b589d"
# test suite app https://octopus-code.org/testsuite/commits/1802
# eb pipeline https://gitlab.com/octopus-code/octopus/-/pipelines/1111292546
# spack pipeline http://mpsd-octopus-code-staging.desy.de/buildbot/#/builders/143/builds/7
# builder_map = {builder:{easybuild:eb_url,spack:spack_url}}
latest_example_map = {
    "foss2022a_mpi": {
        "easybuild": "https://www.octopus-code.org/buildbot/#/builders/108/builds/84",
        "spack": "http://mpsd-octopus-code-staging.desy.de/buildbot/#/builders/101/builds/33",
    },
    "foss2022a_mpi_omp": {
        "easybuild": "https://www.octopus-code.org/buildbot/#/builders/53/builds/1113",
        "spack": "http://mpsd-octopus-code-staging.desy.de/buildbot/#/builders/144/builds/8",
    },
    "foss2022a_mpi_debug": {
        "easybuild": "https://www.octopus-code.org/buildbot/#/builders/161/builds/76",
        "spack": "http://mpsd-octopus-code-staging.desy.de/buildbot/#/builders/158/builds/16",
    }
}

# %%
for builder in latest_example_map:
    left_url = latest_example_map[builder]["easybuild"]
    right_url = latest_example_map[builder]["spack"]
    headding = Markdown(f"""
## {builder=}
### {left_url=}
### {right_url=}
""")
    rprint(headding)
    try:
        left_config_h = get_config_h(left_url)
        right_config_h = get_config_h(right_url)
        diff = get_diff(
            left_config_h, right_config_h, f"eb_{builder}", f"spack_{builder}"
        )
        rprint(diff)
    except:
        rprint(Markdown("### failed to compile results"))
# Out:
#                                               builder='foss2022a_mpi'
#
#                      left_url='https://www.octopus-code.org/buildbot/#/builders/108/builds/84'
#
#               right_url='http://mpsd-octopus-code-staging.desy.de/buildbot/#/builders/101/builds/33'
#
#  --- eb_foss2022a_mpi
#
#  +++ spack_foss2022a_mpi
#
#  @@ -2,7 +2,7 @@
#
#   /* config.h.in.  Generated from configure.ac by autoheader.  */
#
#   /* date when configure was launched */
#  -#define BUILD_TIME "Mon Dec 18 15:32:23 CET 2023"
#  +#define BUILD_TIME "Mon Dec 18 18:42:09 CET 2023"
#
#   /* C compiler */
#   #define CC "mpicc (gcc)"
#  @@ -32,13 +32,13 @@
#
#   #define F90_ACCEPTS_LINE_NUMBERS 1
#
#   /* Fortran compiler */
#  -#define FC "mpifort (gfortran)"
#  +#define FC "mpif90 (gfortran)"
#
#   /* Fortran compiler flags */
#  -#define FCFLAGS "-Wall -Wno-maybe-uninitialized -Wno-surprising -O2 -march=native -fbacktrace -ftest-coverage
#  -fprofile-arcs -fallow-argu"
# ...
